# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation
import time
from tqdm.auto import tqdm

import random as rd

class getPlayerData:
    def __init__(self, a):
        self.name = a

    def search_global(self):
        df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1")
        print(df[df["name"] == self.name.title()])

class setPlayerData(getPlayerData):
    def __init__(self, attrs):
        getPlayerData.__init__(self, name)
        self.attrs = attrs

    def confirm_selection(self):
        label2 = ["Health Points", "Attack", "Defense"]
        colours1 = ["green", "red", "blue"]
        y = np.array(self.attrs[18:21])
        plt.pie(y, labels = label2, colors = colours1, autopct = "%1.1f%%")
        plt.title("Pokemon Stats")
        plt.legend(bbox_to_anchor=(1.1, 1.05))
        plt.show()

        ch = input(f"Are you sure you want to select {self.name}[Yes/No]?")

        if ch.title() == "Yes":
            print(f"You chose: {self.attrs[2]}")
            print(self.attrs)





# noinspection PyGlobalUndefined
def defenseCalc():
    global defense
    if player.attrs[7] == "Normal":
        defense = opponent[18] * opponent[31]
    elif player.attrs[7] == "Fire":
        defense = opponent[18] * opponent[32]
    elif player.attrs[7] == "Water":
        defense = opponent[18] * opponent[33]
    elif player.attrs[7] == "Electric":
        defense = opponent[18] * opponent[34]
    elif player.attrs[7] == "Grass":
        defense = opponent[18] * opponent[35]
    elif player.attrs[7] == "Ice":
        defense = opponent[18] * opponent[36]
    elif player.attrs[7] == "Fighting":
        defense = opponent[18] * opponent[37]
    elif player.attrs[7] == "Poison":
        defense = opponent[18] * opponent[38]
    elif player.attrs[7] == "Ground":
        defense = opponent[18] * opponent[39]
    elif player.attrs[7] == "Flying":
        defense = opponent[18] * opponent[40]
    elif player.attrs[7] == "Psychic":
        defense = opponent[18] * opponent[41]
    elif player.attrs[7] == "Bug":
        defense = opponent[18] * opponent[42]
    elif player.attrs[7] == "Rock":
        defense = opponent[18] * opponent[43]
    elif player.attrs[7] == "Ghost":
        defense = opponent[18] * opponent[44]
    elif player.attrs[7] == "Dragon":
        defense = opponent[18] * opponent[45]
    elif player.attrs[7] == "Dark":
        defense = opponent[18] * opponent[46]
    elif player.attrs[7] == "Steel":
        defense = opponent[18] * opponent[47]
    elif player.attrs[7] == "Fairy":
        defense = opponent[18] * opponent[48]


# noinspection PyGlobalUndefined
def defensePlayerCalc():
    global defensePlayer
    if opponent[7] == "Normal":
        defensePlayer = player.attrs[18] * player.attrs[31]
    elif opponent[7] == "Fire":
        defensePlayer = player.attrs[18] * player.attrs[32]
    elif opponent[7] == "Water":
        defensePlayer = player.attrs[18] * player.attrs[33]
    elif opponent[7] == "Electric":
        defensePlayer = player.attrs[18] * player.attrs[34]
    elif opponent[7] == "Grass":
        defensePlayer = player.attrs[18] * player.attrs[35]
    elif opponent[7] == "Ice":
        defensePlayer = player.attrs[18] * player.attrs[36]
    elif opponent[7] == "Fighting":
        defensePlayer = player.attrs[18] * player.attrs[37]
    elif opponent[7] == "Poison":
        defensePlayer = player.attrs[18] * player.attrs[38]
    elif opponent[7] == "Ground":
        defensePlayer = player.attrs[18] * player.attrs[39]
    elif opponent[7] == "Flying":
        defensePlayer = player.attrs[18] * player.attrs[40]
    elif opponent[7] == "Psychic":
        defensePlayer = player.attrs[18] * player.attrs[41]
    elif opponent[7] == "Bug":
        defensePlayer = player.attrs[18] * player.attrs[42]
    elif opponent[7] == "Rock":
        defensePlayer = player.attrs[18] * player.attrs[43]
    elif opponent[7] == "Ghost":
        defensePlayer = player.attrs[18] * player.attrs[44]
    elif opponent[7] == "Dragon":
        defensePlayer = player.attrs[18] * player.attrs[45]
    elif opponent[7] == "Dark":
        defensePlayer = player.attrs[18] * player.attrs[46]
    elif opponent[7] == "Steel":
        defensePlayer = player.attrs[18] * player.attrs[47]
    elif opponent[7] == "Fairy":
        defensePlayer = player.attrs[18] * player.attrs[48]

while True:
    print('''            = = = = = = = = = = =
            =                   =
            =   Pokémon Brawl   =
            =                   =
            = = = = = = = = = = =''')


    ch2 = int(input('''Enter an Option:
    1. Category Based Search
    2. Direct Search'''))


    if ch2 == 1:
        while True:
            ch3 = int(input('''Choose the Attribute for sorting:
           1. Generation
           2. Status
           3. Species
           4. Type
           '''))



            if ch3 == 1:
                df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", usecols = ["name", "generation"])
                gen = int(input("Enter the Generation Number of the Pokémon: "))
                print(df[df["generation"] == gen])
                name = input("Enter the Name of the Pokémon: ")
                p1 = getPlayerData(name)
                p1.search_global()
                #Getting All Values
                df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", index_col = "name")
                player = setPlayerData(list(df.loc[name]))
                player.confirm_selection()
                break

            elif ch3 == 2:
                df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", usecols = ["name", "status"])
                status = input("Enter the Status of the Pokémon: ")
                print(df[df["status"] == status])
                name = input("Enter the Name of the Pokémon: ")
                p1 = getPlayerData(name)
                p1.search_global()
                #Getting All Values
                df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", index_col = "name")
                player = setPlayerData(list(df.loc[name]))
                player.confirm_selection()
                break

            elif ch3 == 3:
                df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", usecols = ["name", "species"])
                species = input("Enter the Species of the Pokémon: ")
                print(df[df["species"] == species])
                name = input("Enter the Name of the Pokémon: ")
                p1 = getPlayerData(name)
                p1.search_global()
                #Getting All Values
                df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", index_col = "name")
                player = setPlayerData(list(df.loc[name]))
                player.confirm_selection()
                break

            elif ch3 == 4:
                df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", usecols = ["name", "type_1"])
                type1 = input("Enter the Type of the Pokémon: ")
                print(df[df["type_1"] == type1])
                name = input("Enter the Name of the Pokémon: ")
                p1 = getPlayerData(name)
                p1.search_global()
                #Getting All Values
                df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", index_col = "name")
                player = setPlayerData(list(df.loc[name]))
                player.confirm_selection()
                break

            else:
                print("Please enter a valid option!")

    elif ch2 == 2:
        df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", usecols = ["name", "generation"])
        name = input("Enter the Name of the Pokémon: ")
        print(df[df["name"] == name])
        p1 = getPlayerData(name)
        p1.search_global()
        #Getting All Values
        df = pd.read_csv("datasets/pokedex.csv", encoding="ISO-8859-1", index_col = "name")
        player = setPlayerData(list(df.loc[name]))
        player.confirm_selection()


    oppno=rd.randint(1,1044)
    df = pd.read_csv("datasets/pokedex.csv",encoding="ISO-8859-1", index_col ="pokedex_number")
    opponent = list(df.loc[oppno])
    print(f"Your opponent is: {opponent[1]}")
    print(opponent)
    label1 = ["Health Points", "Attack", "Defense"]
    colours = ["green", "red", "blue"]
    y = np.array(opponent[16:19])
    plt.pie(y, labels = label1, colors = colours, autopct = "%1.1f%%")
    plt.title("Opponent Stats")
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.show()

    break

def Round():
        i = 1
        print(f"========================= Round {i} Begins =========================")

        while True:
            if player.attrs[13] == "nan" or player.attrs[14] == "nan":
                print("Please select enter a valid ability!")
            else:
                ch4 = int(input(f'''Choose your ability:
                1. {player.attrs[12]}
                2. {player.attrs[13]}
                3. {player.attrs[14]}'''))

                player_hp = player.attrs[16]
                opponent_hp = opponent[16]
                if ch4 == 1:
                    if opponent[7] == "Normal":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[31]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Fire":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[32]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Water":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[33]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Electric":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[34]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Grass":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[35]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Ice":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[36]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Fighting":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[37]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Poison":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[38]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Ground":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[39]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Flying":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[40]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Psychic":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[41]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Bug":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[42]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Rock":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[43]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Ghost":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[44]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Dragon":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[45]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Dark":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[46]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Steel":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[47]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Fairy":
                        attack = (rd.randint(player.attrs[17] - 10,player.attrs[17] - 5)) * player.attrs[48]
                        defenseCalc()
                        total_atk = attack - defense


                elif ch4 == 2:
                    if opponent[7] == "Normal":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[31]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Fire":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[32]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Water":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[33]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Electric":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[34]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Grass":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[35]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Ice":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[36]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Fighting":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[37]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Poison":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[38]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Ground":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[39]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Flying":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[40]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Psychic":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[41]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Bug":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[42]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Rock":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[43]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Ghost":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[44]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Dragon":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[45]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Dark":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[46]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Steel":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[47]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Fairy":
                        attack = (rd.randint(player.attrs[17] + 5,player.attrs[17] + 10)) * player.attrs[48]
                        defenseCalc()
                        total_atk = attack - defense


                elif ch4 == 3:
                    if opponent[7] == "Normal":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[31]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Fire":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[32]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Water":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[33]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Electric":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[34]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Grass":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[35]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Ice":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[36]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Fighting":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[37]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Poison":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[38]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Ground":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[39]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Flying":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[40]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Psychic":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[41]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Bug":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[42]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Rock":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[43]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Ghost":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[44]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Dragon":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[45]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Dark":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[46]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Steel":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[47]
                        defenseCalc()
                        total_atk = attack - defense

                    elif opponent[7] == "Fairy":
                        attack = (rd.randint(player.attrs[17] + 15,player.attrs[17] + 25)) * player.attrs[48]
                        defenseCalc()
                        total_atk = attack - defense
            break

        if total_atk>0:
            opponent_hp -= total_atk
            if opponent_hp > 0:
                print(f'''The attack was successful.
                        1. Total Damage Delivered - {total_atk}
                        2. Opponent HP remaining - {opponent_hp}''')
            elif opponent_hp <= 0:
                print(f'''The attack was successful.
                        1. Total Damage Delivered - {total_atk}
                        2. Opponent HP remaining - 0''')


        else:
            print("Your attack was resisted by the opponent.")

        print("Opponent Attacking...")

        for i in tqdm(range(10001)):
            print(" ", end = '\r')

        while True:
            if opponent[7] == "Normal":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[31]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Fire":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[32]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Water":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[33]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Electric":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[34]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Grass":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[35]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Ice":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[36]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Fighting":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[37]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Poison":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[38]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Ground":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[39]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Flying":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[40]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Psychic":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[41]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Bug":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[42]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Rock":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[43]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Ghost":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[44]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Dragon":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[45]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Dark":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[46]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Steel":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[47]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer

            elif opponent[7] == "Fairy":
                attack = (rd.randint(opponent[17] + 5,opponent[17] + 10)) * opponent[48]
                defensePlayerCalc()
                total_atk_opp = attack - defensePlayer
            break

        if total_atk_opp>0:
            player_hp -= total_atk_opp
            if player_hp > 0:
                print(f'''The opponent attack was successful.
                        1. Total Damage Delivered - {total_atk_opp}
                        2. Your HP remaining - {player_hp}''')

            elif player_hp <= 0:
                print(f'''The opponent attack was successful.
                        1. Total Damage Delivered - {total_atk_opp}
                        2. Your HP remaining - 0''')

        else:
            print(f"The attack was resisted by your Pokémon: {player.attrs[2]}.")

        i += 1

Round()
# Out:
#             = = = = = = = = = = =
#             =                   =
#             =   Pokémon Brawl   =
#             =                   =
#             = = = = = = = = = = =
#        name  generation
# 32  Pikachu           1
#     Unnamed: 0  pokedex_number     name german_name  generation  status  \
# 32          32              25  Pikachu     Pikachu           1  Normal
#
#           species  type_number    type_1 type_2  ...  against_ground  \
# 32  Mouse Pokémon            1  Electric    NaN  ...             2.0
#
#     against_flying  against_psychic against_bug against_rock against_ghost  \
# 32             0.5              1.0         1.0          1.0           1.0
#
#     against_dragon  against_dark  against_steel  against_fairy
# 32             1.0           1.0            0.5            1.0
#
# [1 rows x 50 columns]
# You chose: Pikachu
# ...
